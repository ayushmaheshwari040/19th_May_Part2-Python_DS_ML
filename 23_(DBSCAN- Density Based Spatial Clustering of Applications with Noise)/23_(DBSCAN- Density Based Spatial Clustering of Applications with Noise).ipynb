# %% [markdown]
# # Some Points in DBSCAN

# %% [markdown]
# 1. Used for clustering data points based on their density.
# 2. It identifies clusters as dense regions of data points that are separated by areas of lower density, which are often considered noise or outliers.
# 3. It is used to identify the nested clusters.
