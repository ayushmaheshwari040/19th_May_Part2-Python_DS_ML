# %%
import numpy  as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### date range

# %%
pd.date_range("28/04/25", periods=10)
# Out:
# DatetimeIndex(['2025-04-28', '2025-04-29', '2025-04-30', '2025-05-01',
#                '2025-05-02', '2025-05-03', '2025-05-04', '2025-05-05',
#                '2025-05-06', '2025-05-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range("28/04/25", periods=10, freq='2D')
# Out:
# DatetimeIndex(['2025-04-28', '2025-04-30', '2025-05-02', '2025-05-04',
#                '2025-05-06', '2025-05-08', '2025-05-10', '2025-05-12',
#                '2025-05-14', '2025-05-16'],
#               dtype='datetime64[ns]', freq='2D')

# %%
pd.date_range("28/04/25", "13/05/25")
# Out:
# DatetimeIndex(['2025-04-28', '2025-04-29', '2025-04-30', '2025-05-01',
#                '2025-05-02', '2025-05-03', '2025-05-04', '2025-05-05',
#                '2025-05-06', '2025-05-07', '2025-05-08', '2025-05-09',
#                '2025-05-10', '2025-05-11', '2025-05-12', '2025-05-13'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range("28/04/25", "13/05/25", freq='5D')
# Out:
# DatetimeIndex(['2025-04-28', '2025-05-03', '2025-05-08', '2025-05-13'], dtype='datetime64[ns]', freq='5D')

# %%
pd.date_range("29/04/25 6:00am", periods=10)
# Out:
# DatetimeIndex(['2025-04-29 06:00:00', '2025-04-30 06:00:00',
#                '2025-05-01 06:00:00', '2025-05-02 06:00:00',
#                '2025-05-03 06:00:00', '2025-05-04 06:00:00',
#                '2025-05-05 06:00:00', '2025-05-06 06:00:00',
#                '2025-05-07 06:00:00', '2025-05-08 06:00:00'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range("29/04/25 6:00am", periods=7, freq='2H')
# Out:
# DatetimeIndex(['2025-04-29 06:00:00', '2025-04-29 08:00:00',
#                '2025-04-29 10:00:00', '2025-04-29 12:00:00',
#                '2025-04-29 14:00:00', '2025-04-29 16:00:00',
#                '2025-04-29 18:00:00'],
#               dtype='datetime64[ns]', freq='2H')

# %%
pd.date_range("29/04/25 6:00am", periods=7, freq='30T')
# Out:
# DatetimeIndex(['2025-04-29 06:00:00', '2025-04-29 06:30:00',
#                '2025-04-29 07:00:00', '2025-04-29 07:30:00',
#                '2025-04-29 08:00:00', '2025-04-29 08:30:00',
#                '2025-04-29 09:00:00'],
#               dtype='datetime64[ns]', freq='30T')

# %%
temp = [20.0, 22.2, 25.5, 27.4, 30.6, 29.8, 25.4 ]

# %%
dates = pd.date_range("28/04/25 6:00am", periods=7, freq='2H')
dates
# Out:
# DatetimeIndex(['2025-04-28 06:00:00', '2025-04-28 08:00:00',
#                '2025-04-28 10:00:00', '2025-04-28 12:00:00',
#                '2025-04-28 14:00:00', '2025-04-28 16:00:00',
#                '2025-04-28 18:00:00'],
#               dtype='datetime64[ns]', freq='2H')

# %%
sr = pd.Series(temp, dates)
sr
# Out:
# 2025-04-28 06:00:00    20.0
# 2025-04-28 08:00:00    22.2
# 2025-04-28 10:00:00    25.5
# 2025-04-28 12:00:00    27.4
# 2025-04-28 14:00:00    30.6
# 2025-04-28 16:00:00    29.8
# 2025-04-28 18:00:00    25.4
# Freq: 2H, dtype: float64

# %% [markdown]
# ##### resampling

# %%
sr.resample()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 sr.resample()
#
# TypeError: NDFrame.resample() missing 1 required positional argument: 'rule'

# %%
sr.resample('3H')

# %%
sr
# Out:
# 2025-04-28 06:00:00    20.0
# 2025-04-28 08:00:00    22.2
# 2025-04-28 10:00:00    25.5
# 2025-04-28 12:00:00    27.4
# 2025-04-28 14:00:00    30.6
# 2025-04-28 16:00:00    29.8
# 2025-04-28 18:00:00    25.4
# Freq: 2H, dtype: float64

# %%
sr.resample('3H').mean()
# Out:
# 2025-04-28 06:00:00    21.1
# 2025-04-28 09:00:00    25.5
# 2025-04-28 12:00:00    29.0
# 2025-04-28 15:00:00    29.8
# 2025-04-28 18:00:00    25.4
# Freq: 3H, dtype: float64

# %%
sr
# Out:
# 2025-04-28 06:00:00    20.0
# 2025-04-28 08:00:00    22.2
# 2025-04-28 10:00:00    25.5
# 2025-04-28 12:00:00    27.4
# 2025-04-28 14:00:00    30.6
# 2025-04-28 16:00:00    29.8
# 2025-04-28 18:00:00    25.4
# Freq: 2H, dtype: float64

# %%
sr.resample('4H').min()
# Out:
# 2025-04-28 04:00:00    20.0
# 2025-04-28 08:00:00    22.2
# 2025-04-28 12:00:00    27.4
# 2025-04-28 16:00:00    25.4
# Freq: 4H, dtype: float64

# %%
sr.resample('4H').max()
# Out:
# 2025-04-28 04:00:00    20.0
# 2025-04-28 08:00:00    25.5
# 2025-04-28 12:00:00    30.6
# 2025-04-28 16:00:00    29.8
# Freq: 4H, dtype: float64

# %%
sr.resample('1H').mean()
# Out:
# 2025-04-28 06:00:00    20.0
# 2025-04-28 07:00:00     NaN
# 2025-04-28 08:00:00    22.2
# 2025-04-28 09:00:00     NaN
# 2025-04-28 10:00:00    25.5
# 2025-04-28 11:00:00     NaN
# 2025-04-28 12:00:00    27.4
# 2025-04-28 13:00:00     NaN
# 2025-04-28 14:00:00    30.6
# 2025-04-28 15:00:00     NaN
# 2025-04-28 16:00:00    29.8
# 2025-04-28 17:00:00     NaN
# 2025-04-28 18:00:00    25.4
# Freq: H, dtype: float64

# %%
sr
# Out:
# 2025-04-28 06:00:00    20.0
# 2025-04-28 08:00:00    22.2
# 2025-04-28 10:00:00    25.5
# 2025-04-28 12:00:00    27.4
# 2025-04-28 14:00:00    30.6
# 2025-04-28 16:00:00    29.8
# 2025-04-28 18:00:00    25.4
# Freq: 2H, dtype: float64

# %%
resample = sr.resample('1H').mean().interpolate()
resample
# Out:
# 2025-04-28 06:00:00    20.00
# 2025-04-28 07:00:00    21.10
# 2025-04-28 08:00:00    22.20
# 2025-04-28 09:00:00    23.85
# 2025-04-28 10:00:00    25.50
# 2025-04-28 11:00:00    26.45
# 2025-04-28 12:00:00    27.40
# 2025-04-28 13:00:00    29.00
# 2025-04-28 14:00:00    30.60
# 2025-04-28 15:00:00    30.20
# 2025-04-28 16:00:00    29.80
# 2025-04-28 17:00:00    27.60
# 2025-04-28 18:00:00    25.40
# Freq: H, dtype: float64

# %%
sr.plot()
# Out:
# <Axes: >

# %%
resample.plot()
# Out:
# <Axes: >

# %%
sr
# Out:
# 2025-04-28 06:00:00    20.0
# 2025-04-28 08:00:00    22.2
# 2025-04-28 10:00:00    25.5
# 2025-04-28 12:00:00    27.4
# 2025-04-28 14:00:00    30.6
# 2025-04-28 16:00:00    29.8
# 2025-04-28 18:00:00    25.4
# Freq: 2H, dtype: float64

# %%
resample = sr.resample('1H').mean().interpolate('cubic')
resample
# Out:
# 2025-04-28 06:00:00    20.000000
# 2025-04-28 07:00:00    20.677121
# 2025-04-28 08:00:00    22.200000
# 2025-04-28 09:00:00    23.997879
# 2025-04-28 10:00:00    25.500000
# 2025-04-28 11:00:00    26.393862
# 2025-04-28 12:00:00    27.400000
# 2025-04-28 13:00:00    29.114174
# 2025-04-28 14:00:00    30.600000
# 2025-04-28 15:00:00    30.811942
# 2025-04-28 16:00:00    29.800000
# 2025-04-28 17:00:00    27.888058
# 2025-04-28 18:00:00    25.400000
# Freq: H, dtype: float64

# %%
sr.plot()
# Out:
# <Axes: >

# %%
resample.plot()
# Out:
# <Axes: >

# %%
resample = sr.resample('1H').mean().interpolate('nearest')
resample
# Out:
# 2025-04-28 06:00:00    20.0
# 2025-04-28 07:00:00    20.0
# 2025-04-28 08:00:00    22.2
# 2025-04-28 09:00:00    22.2
# 2025-04-28 10:00:00    25.5
# 2025-04-28 11:00:00    25.5
# 2025-04-28 12:00:00    27.4
# 2025-04-28 13:00:00    27.4
# 2025-04-28 14:00:00    30.6
# 2025-04-28 15:00:00    30.6
# 2025-04-28 16:00:00    29.8
# 2025-04-28 17:00:00    29.8
# 2025-04-28 18:00:00    25.4
# Freq: H, dtype: float64

# %%
resample = sr.resample('30T').mean().interpolate()
resample
# Out:
# 2025-04-28 06:00:00    20.000
# 2025-04-28 06:30:00    20.550
# 2025-04-28 07:00:00    21.100
# 2025-04-28 07:30:00    21.650
# 2025-04-28 08:00:00    22.200
# 2025-04-28 08:30:00    23.025
# 2025-04-28 09:00:00    23.850
# 2025-04-28 09:30:00    24.675
# 2025-04-28 10:00:00    25.500
# 2025-04-28 10:30:00    25.975
# 2025-04-28 11:00:00    26.450
# 2025-04-28 11:30:00    26.925
# 2025-04-28 12:00:00    27.400
# 2025-04-28 12:30:00    28.200
# 2025-04-28 13:00:00    29.000
# 2025-04-28 13:30:00    29.800
# 2025-04-28 14:00:00    30.600
# 2025-04-28 14:30:00    30.400
# 2025-04-28 15:00:00    30.200
# 2025-04-28 15:30:00    30.000
# 2025-04-28 16:00:00    29.800
# 2025-04-28 16:30:00    28.700
# 2025-04-28 17:00:00    27.600
# 2025-04-28 17:30:00    26.500
# 2025-04-28 18:00:00    25.400
# Freq: 30T, dtype: float64

# %%
resample.plot()
# Out:
# <Axes: >

# %%
netflix = pd.read_csv('netflix-rotten-tomatoes-metacritic-imdb.csv')
netflix
# Out:
#                                            Title  \
# 0                               Lets Fight Ghost
# 1                            HOW TO BUILD A GIRL
# 2                                     Centigrade
# 3                                          ANNE+
# 4                                          Moxie
# ...                                          ...
# 15475                     K-POP Extreme Survival
# 15476            DreamWorks Shreks Swamp Stories
# 15477  DreamWorks Happy Holidays from Madagascar
# 15478                DreamWorks Holiday Classics
# 15479   DreamWorks Kung Fu Panda Awesome Secrets
#
#                                         Genre  \
# 0      Crime, Drama, Fantasy, Horror, Romance
# 1                                      Comedy
# 2                             Drama, Thriller
# 3                                       Drama
# 4                     Animation, Short, Drama
# ...                                       ...
# ...

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15480 entries, 0 to 15479
# Data columns (total 29 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  15480 non-null  object
#  1   Genre                  13770 non-null  object
#  2   Tags                   15413 non-null  object
#  3   Languages              13526 non-null  object
#  4   Series or Movie        15480 non-null  object
#  5   Hidden Gem Score       13379 non-null  float64
#  6   Country Availability   15461 non-null  object
#  7   Runtime                15479 non-null  object
#  8   Director               10772 non-null  object
#  9   Writer                 11150 non-null  object
#  10  Actors                 13555 non-null  object
#  11  View Rating            8456 non-null   object
#  12  IMDb Score             13381 non-null  float64
#  13  Rotten Tomatoes Score  6382 non-null   float64
# ...

# %%
netflix.head()
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2                                          Thrillers           English
# 3        TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4  Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
#
#   Series or Movie  Hidden Gem Score  \
# 0          Series               4.3
# 1           Movie               7.0
# 2           Movie               6.4
# ...

# %%
netflix.head(n=20)
# Out:
#                          Title                                     Genre  \
# 0             Lets Fight Ghost    Crime, Drama, Fantasy, Horror, Romance
# 1          HOW TO BUILD A GIRL                                    Comedy
# 2                   Centigrade                           Drama, Thriller
# 3                        ANNE+                                     Drama
# 4                        Moxie                   Animation, Short, Drama
# 5             The Con-Heartist                           Comedy, Romance
# 6                 Gleboka woda                                     Drama
# 7                     Instynkt                                     Crime
# 8                Only a Mother                                     Drama
# 9                   Snowroller                                    Comedy
# 10                Sunes Summer                   Comedy, Family, Fantasy
# 11               The Invisible  Crime, Drama, Fantasy, Mystery, Thriller
# ...

# %%
netflix.tail()
# Out:
#                                            Title  \
# 15475                     K-POP Extreme Survival
# 15476            DreamWorks Shreks Swamp Stories
# 15477  DreamWorks Happy Holidays from Madagascar
# 15478                DreamWorks Holiday Classics
# 15479   DreamWorks Kung Fu Panda Awesome Secrets
#
#                                    Genre  \
# 15475                                NaN
# 15476                                NaN
# 15477          Animation, Comedy, Family
# 15478          Animation, Comedy, Family
# 15479  Animation, Action, Comedy, Family
#
#                                                     Tags Languages  \
# 15475  TV Dramas,TV Programmes,TV Comedies,Romantic T...       NaN
# 15476  Animal Tales,Family Comedies,Family Adventures...       NaN
# 15477  TV Comedies,Kids TV,Animal Tales,TV Cartoons,T...   English
# 15478  TV Comedies,Kids TV,TV Cartoons,TV Programmes,...   English
# 15479  TV Comedies,Kids TV,Animal Tales,TV Cartoons,T...   English
#
# ...

# %%
netflix.isna().sum()
# Out:
# Title                        0
# Genre                     1710
# Tags                        67
# Languages                 1954
# Series or Movie              0
# Hidden Gem Score          2101
# Country Availability        19
# Runtime                      1
# Director                  4708
# Writer                    4330
# Actors                    1925
# View Rating               7024
# IMDb Score                2099
# Rotten Tomatoes Score     9098
# Metacritic Score         11144
# Awards Received           9405
# Awards Nominated For      7819
# Boxoffice                11473
# Release Date              2107
# Netflix Release Date         0
# Production House         10331
# Netflix Link                 0
# IMDb Link                 2303
# Summary                      9
# IMDb Votes                2101
# Image                        0
# Poster                    3638
# TMDb Trailer              8286
# Trailer Site              8286
# dtype: int64

# %%
netflix.isna().sum().sort_values()
# Out:
# Title                        0
# Netflix Release Date         0
# Image                        0
# Series or Movie              0
# Netflix Link                 0
# Runtime                      1
# Summary                      9
# Country Availability        19
# Tags                        67
# Genre                     1710
# Actors                    1925
# Languages                 1954
# IMDb Score                2099
# IMDb Votes                2101
# Hidden Gem Score          2101
# Release Date              2107
# IMDb Link                 2303
# Poster                    3638
# Writer                    4330
# Director                  4708
# View Rating               7024
# Awards Nominated For      7819
# Trailer Site              8286
# TMDb Trailer              8286
# Rotten Tomatoes Score     9098
# Awards Received           9405
# Production House         10331
# Metacritic Score         11144
# Boxoffice                11473
# dtype: int64

# %%
netflix.isna().sum().sort_values(ascending=False)
# Out:
# Boxoffice                11473
# Metacritic Score         11144
# Production House         10331
# Awards Received           9405
# Rotten Tomatoes Score     9098
# TMDb Trailer              8286
# Trailer Site              8286
# Awards Nominated For      7819
# View Rating               7024
# Director                  4708
# Writer                    4330
# Poster                    3638
# IMDb Link                 2303
# Release Date              2107
# Hidden Gem Score          2101
# IMDb Votes                2101
# IMDb Score                2099
# Languages                 1954
# Actors                    1925
# Genre                     1710
# Tags                        67
# Country Availability        19
# Summary                      9
# Runtime                      1
# Netflix Link                 0
# Image                        0
# Netflix Release Date         0
# Series or Movie              0
# Title                        0
# dtype: int64

# %%
netflix.shape[0]
# Out:
# 15480

# %%
(netflix.isna().sum() / netflix.shape[0] * 100).sort_values(ascending=False)
# Out:
# Boxoffice                74.114987
# Metacritic Score         71.989664
# Production House         66.737726
# Awards Received          60.755814
# Rotten Tomatoes Score    58.772610
# TMDb Trailer             53.527132
# Trailer Site             53.527132
# Awards Nominated For     50.510336
# View Rating              45.374677
# Director                 30.413437
# Writer                   27.971576
# Poster                   23.501292
# IMDb Link                14.877261
# Release Date             13.611111
# Hidden Gem Score         13.572351
# IMDb Votes               13.572351
# IMDb Score               13.559432
# Languages                12.622739
# Actors                   12.435401
# Genre                    11.046512
# Tags                      0.432817
# Country Availability      0.122739
# Summary                   0.058140
# Runtime                   0.006460
# Netflix Link              0.000000
# Image                     0.000000
# Netflix Release Date      0.000000
# ...

# %%
data = pd.DataFrame({
    'salary':np.random.randint(30, 90, 20),
    'height':np.random.randint(120, 187, 20),
    'weight':np.random.randint(40, 90, 20),
    'gender':np.random.choice(['male', 'female'], 20, True),
    'country':np.random.choice(['india', 'aus', 'china', 'usa'], 20, True)
}, index=[chr(65+i) for i in range(20)])
data
# Out:
#    salary  height  weight  gender country
# A      88     135      76  female   india
# B      61     157      46    male   india
# C      57     121      56  female     aus
# D      84     144      46    male   china
# E      36     162      74  female     usa
# F      67     145      46  female     aus
# G      86     170      53    male   india
# H      76     146      40  female     usa
# I      63     184      43  female   india
# J      35     172      67    male     usa
# K      72     147      76    male     aus
# L      59     144      80    male   china
# M      33     159      48    male   china
# N      60     175      60  female   india
# O      80     184      68    male   india
# P      62     178      41    male     aus
# Q      70     148      83  female   china
# R      87     135      43  female   india
# S      65     167      82  female   china
# T      31     139      74  female     usa

# %%
data.iloc[1:8:2, [0,1,2]] = np.nan

# %%
data
# Out:
#    salary  height  weight  gender country
# A    88.0   135.0    76.0  female   india
# B     NaN     NaN     NaN    male   india
# C    57.0   121.0    56.0  female     aus
# D     NaN     NaN     NaN    male   china
# E    36.0   162.0    74.0  female     usa
# F     NaN     NaN     NaN  female     aus
# G    86.0   170.0    53.0    male   india
# H     NaN     NaN     NaN  female     usa
# I    63.0   184.0    43.0  female   india
# J    35.0   172.0    67.0    male     usa
# K    72.0   147.0    76.0    male     aus
# L    59.0   144.0    80.0    male   china
# M    33.0   159.0    48.0    male   china
# N    60.0   175.0    60.0  female   india
# O    80.0   184.0    68.0    male   india
# P    62.0   178.0    41.0    male     aus
# Q    70.0   148.0    83.0  female   china
# R    87.0   135.0    43.0  female   india
# S    65.0   167.0    82.0  female   china
# T    31.0   139.0    74.0  female     usa

# %%
data.describe()
# Out:
#           salary      height     weight
# count  16.000000   16.000000  16.000000
# mean   61.500000  157.500000  64.000000
# std    19.349419   19.459359  14.881756
# min    31.000000  121.000000  41.000000
# 25%    51.750000  142.750000  51.750000
# 50%    62.500000  160.500000  67.500000
# 75%    74.000000  172.750000  76.000000
# max    88.000000  184.000000  83.000000

# %%
data
# Out:
#    salary  height  weight  gender country
# A    88.0   135.0    76.0  female   india
# B     NaN     NaN     NaN    male   india
# C    57.0   121.0    56.0  female     aus
# D     NaN     NaN     NaN    male   china
# E    36.0   162.0    74.0  female     usa
# F     NaN     NaN     NaN  female     aus
# G    86.0   170.0    53.0    male   india
# H     NaN     NaN     NaN  female     usa
# I    63.0   184.0    43.0  female   india
# J    35.0   172.0    67.0    male     usa
# K    72.0   147.0    76.0    male     aus
# L    59.0   144.0    80.0    male   china
# M    33.0   159.0    48.0    male   china
# N    60.0   175.0    60.0  female   india
# O    80.0   184.0    68.0    male   india
# P    62.0   178.0    41.0    male     aus
# Q    70.0   148.0    83.0  female   china
# R    87.0   135.0    43.0  female   india
# S    65.0   167.0    82.0  female   china
# T    31.0   139.0    74.0  female     usa

# %%
data['salary'].median()
# Out:
# 62.5

# %%
data['salary'].fillna(data['salary'].median())
# Out:
# A    88.0
# B    62.5
# C    57.0
# D    62.5
# E    36.0
# F    62.5
# G    86.0
# H    62.5
# I    63.0
# J    35.0
# K    72.0
# L    59.0
# M    33.0
# N    60.0
# O    80.0
# P    62.0
# Q    70.0
# R    87.0
# S    65.0
# T    31.0
# Name: salary, dtype: float64

# %%
data['salary'].fillna(data['salary'].median(), inplace=True)

# %%
data
# Out:
#    salary  height  weight  gender country
# A    88.0   135.0    76.0  female   india
# B    62.5     NaN     NaN    male   india
# C    57.0   121.0    56.0  female     aus
# D    62.5     NaN     NaN    male   china
# E    36.0   162.0    74.0  female     usa
# F    62.5     NaN     NaN  female     aus
# G    86.0   170.0    53.0    male   india
# H    62.5     NaN     NaN  female     usa
# I    63.0   184.0    43.0  female   india
# J    35.0   172.0    67.0    male     usa
# K    72.0   147.0    76.0    male     aus
# L    59.0   144.0    80.0    male   china
# M    33.0   159.0    48.0    male   china
# N    60.0   175.0    60.0  female   india
# O    80.0   184.0    68.0    male   india
# P    62.0   178.0    41.0    male     aus
# Q    70.0   148.0    83.0  female   china
# R    87.0   135.0    43.0  female   india
# S    65.0   167.0    82.0  female   china
# T    31.0   139.0    74.0  female     usa

# %%
data.describe()
# Out:
#           salary      height     weight
# count  20.000000   16.000000  16.000000
# mean   61.700000  157.500000  64.000000
# std    17.197307   19.459359  14.881756
# min    31.000000  121.000000  41.000000
# 25%    58.500000  142.750000  51.750000
# 50%    62.500000  160.500000  67.500000
# 75%    70.500000  172.750000  76.000000
# max    88.000000  184.000000  83.000000

# %%
netflix
# Out:
#                                            Title  \
# 0                               Lets Fight Ghost
# 1                            HOW TO BUILD A GIRL
# 2                                     Centigrade
# 3                                          ANNE+
# 4                                          Moxie
# ...                                          ...
# 15475                     K-POP Extreme Survival
# 15476            DreamWorks Shreks Swamp Stories
# 15477  DreamWorks Happy Holidays from Madagascar
# 15478                DreamWorks Holiday Classics
# 15479   DreamWorks Kung Fu Panda Awesome Secrets
#
#                                         Genre  \
# 0      Crime, Drama, Fantasy, Horror, Romance
# 1                                      Comedy
# 2                             Drama, Thriller
# 3                                       Drama
# 4                     Animation, Short, Drama
# ...                                       ...
# ...

# %%
(netflix.isna().sum() / netflix.shape[0] * 100).sort_values(ascending=False)
# Out:
# Boxoffice                74.114987
# Metacritic Score         71.989664
# Production House         66.737726
# Awards Received          60.755814
# Rotten Tomatoes Score    58.772610
# TMDb Trailer             53.527132
# Trailer Site             53.527132
# Awards Nominated For     50.510336
# View Rating              45.374677
# Director                 30.413437
# Writer                   27.971576
# Poster                   23.501292
# IMDb Link                14.877261
# Release Date             13.611111
# Hidden Gem Score         13.572351
# IMDb Votes               13.572351
# IMDb Score               13.559432
# Languages                12.622739
# Actors                   12.435401
# Genre                    11.046512
# Tags                      0.432817
# Country Availability      0.122739
# Summary                   0.058140
# Runtime                   0.006460
# Netflix Link              0.000000
# Image                     0.000000
# Netflix Release Date      0.000000
# ...

# %%
netflix
# Out:
#                                            Title  \
# 0                               Lets Fight Ghost
# 1                            HOW TO BUILD A GIRL
# 2                                     Centigrade
# 3                                          ANNE+
# 4                                          Moxie
# ...                                          ...
# 15475                     K-POP Extreme Survival
# 15476            DreamWorks Shreks Swamp Stories
# 15477  DreamWorks Happy Holidays from Madagascar
# 15478                DreamWorks Holiday Classics
# 15479   DreamWorks Kung Fu Panda Awesome Secrets
#
#                                         Genre  \
# 0      Crime, Drama, Fantasy, Horror, Romance
# 1                                      Comedy
# 2                             Drama, Thriller
# 3                                       Drama
# 4                     Animation, Short, Drama
# ...                                       ...
# ...

# %%
netflix['Series or Movie']
# Out:
# 0        Series
# 1         Movie
# 2         Movie
# 3        Series
# 4         Movie
#           ...
# 15475    Series
# 15476    Series
# 15477    Series
# 15478    Series
# 15479    Series
# Name: Series or Movie, Length: 15480, dtype: object

# %%
netflix['Series or Movie'].nunique()
# Out:
# 2

# %%
netflix['Series or Movie'].unique()
# Out:
# array(['Series', 'Movie'], dtype=object)

# %%
netflix['Series or Movie'].value_counts()
# Out:
# Series or Movie
# Movie     11697
# Series     3783
# Name: count, dtype: int64

# %%
netflix.head()
# Out:
#                  Title                                   Genre  \
# 0     Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1  HOW TO BUILD A GIRL                                  Comedy
# 2           Centigrade                         Drama, Thriller
# 3                ANNE+                                   Drama
# 4                Moxie                 Animation, Short, Drama
#
#                                                 Tags         Languages  \
# 0  Comedy Programmes,Romantic TV Comedies,Horror ...  Swedish, Spanish
# 1       Dramas,Comedies,Films Based on Books,British           English
# 2                                          Thrillers           English
# 3        TV Dramas,Romantic TV Dramas,Dutch TV Shows           Turkish
# 4  Social Issue Dramas,Teen Movies,Dramas,Comedie...           English
#
#   Series or Movie  Hidden Gem Score  \
# 0          Series               4.3
# 1           Movie               7.0
# 2           Movie               6.4
# ...

# %%
netflix['Languages'].value_counts()
# Out:
# Languages
# English                        5133
# Japanese                       1213
# Korean                          541
# Spanish                         382
# Hindi                           329
#                                ...
# Hungarian, French, English        1
# Arabic, Nyanja, English           1
# Dutch, Flemish                    1
# Thai, Japanese                    1
# English, Hawaiian, Mandarin       1
# Name: count, Length: 1437, dtype: int64

# %%
netflix[netflix['Languages'] == 'Hindi']
# Out:
#                        Title                                   Genre  \
# 24           Indoo Ki Jawani                           Comedy, Drama
# 126           Eeb Allay Ooo!                           Comedy, Drama
# 141     Awara Paagal Deewana  Action, Comedy, Crime, Drama, Thriller
# 189    Dont be the First one                 Action, Crime, Thriller
# 395            Hello Brother        Action, Comedy, Fantasy, Romance
# ...                      ...                                     ...
# 13863                Fashion                                   Drama
# 13885     Ek Main Aur Ekk Tu                  Comedy, Drama, Romance
# 13925                   Boss            Action, Comedy, Crime, Drama
# 13997             Special 26                  Crime, Drama, Thriller
# 14764                   I Am          Documentary, Biography, Family
#
#                                                     Tags Languages  \
# 24     Action & Adventure,Bollywood Films,Comedies,Ad...     Hindi
# ...

# %% [markdown]
#     drop the column containing missing values more than 50 %
