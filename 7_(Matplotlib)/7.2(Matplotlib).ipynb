# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
(tips['sex'].value_counts()).plot(kind='bar', color=['r','g'])
# Out:
# <Axes: xlabel='sex'>

# %%
tips['sex'].value_counts()
# Out:
# sex
# Male      157
# Female     87
# Name: count, dtype: int64

# %%
i1 = tips['sex'].value_counts().index
v1 = tips['sex'].value_counts().values

# %%
i1
# Out:
# CategoricalIndex(['Male', 'Female'], categories=['Male', 'Female'], ordered=False, dtype='category', name='sex')

# %%
v1
# Out:
# array([157,  87], dtype=int64)

# %%
plt.bar(i1, v1, color=['r', 'g', 'b'])
# Out:
# <BarContainer object of 2 artists>

# %%
i2 = tips['smoker'].value_counts().index
i2
# Out:
# CategoricalIndex(['No', 'Yes'], categories=['Yes', 'No'], ordered=False, dtype='category', name='smoker')

# %%
v2 = tips['smoker'].value_counts().values
v2
# Out:
# array([151,  93], dtype=int64)

# %%
plt.figure(figsize=(14,6), dpi=200)
plt.bar(i1, v1, color=['r', 'g', 'b'])
plt.bar(i2, v2, color=['b', 'r'])
plt.show()

# %% [markdown]
# ### Scatter plot

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.figure(figsize=(15,7), dpi=200)
plt.scatter(tips['total_bill'], tips['tip'])
plt.xlabel('Total_bill', size=15)
plt.ylabel('Tip', size=15)
plt.show()

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
plt.figure(figsize=(15,7), dpi=200)
plt.scatter(tips['total_bill'], tips['tip'])
plt.xlabel('Total_bill', size=15)
plt.ylabel('Tip', size=15)
plt.show()

# %%
c = tips['sex'].map({
    'Male':'k',
    'Female':'b'
})
c
# Out:
# 0      b
# 1      k
# 2      k
# 3      k
# 4      b
#       ..
# 239    k
# 240    b
# 241    k
# 242    k
# 243    b
# Name: sex, Length: 244, dtype: category
# Categories (2, object): ['k', 'b']

# %%
plt.figure(figsize=(15,7), dpi=200)
plt.scatter(tips['total_bill'], tips['tip'], c=c)
plt.xlabel('Total_bill', size=15)
plt.ylabel('Tip', size=15)
plt.show()

# %%
fig = plt.figure(figsize=(15,7), dpi=200)
ax = fig.gca()
ax.set_facecolor('c')
plt.scatter(tips['total_bill'], tips['tip'], c=c)
plt.xlabel('Total_bill', size=15)
plt.ylabel('Tip', size=15)
plt.show()

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
taxis = sns.load_dataset('taxis')
taxis
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
i1 = taxis['color'].value_counts().index
v1 = taxis['color'].value_counts().values

# %%
i1
# Out:
# Index(['yellow', 'green'], dtype='object', name='color')

# %%
v1
# Out:
# array([5451,  982], dtype=int64)

# %%
i2 = taxis['payment'].value_counts().index
v2 = taxis['payment'].value_counts().values

# %%
i2
# Out:
# Index(['credit card', 'cash'], dtype='object', name='payment')

# %%
v2
# Out:
# array([4577, 1812], dtype=int64)

# %%
plt.figure(figsize=(15, 6), dpi=200)
plt.bar(i1, v1)
plt.bar(i2, v2)
plt.show()

# %%
plt.figure(figsize=(15, 7), dpi=200)
plt.scatter(taxis['distance'], taxis['fare'])
plt.show()

# %%
taxis['color'].value_counts()
# Out:
# color
# yellow    5451
# green      982
# Name: count, dtype: int64

# %%
c = taxis['color'].map({'yellow':'y', 'green':'g'})
c
# Out:
# 0       y
# 1       y
# 2       y
# 3       y
# 4       y
#        ..
# 6428    g
# 6429    g
# 6430    g
# 6431    g
# 6432    g
# Name: color, Length: 6433, dtype: object

# %%
plt.figure(figsize=(15, 7), dpi=200)
plt.scatter(taxis['distance'], taxis['fare'], c=c)
plt.show()

# %%
taxis['payment'].value_counts()
# Out:
# payment
# credit card    4577
# cash           1812
# Name: count, dtype: int64

# %%
s = taxis['payment'].map({'credit card':15, 'cash':30})
s
# Out:
# 0       15.0
# 1       30.0
# 2       15.0
# 3       15.0
# 4       15.0
#         ...
# 6428    15.0
# 6429    15.0
# 6430    30.0
# 6431    15.0
# 6432    15.0
# Name: payment, Length: 6433, dtype: float64

# %%
plt.figure(figsize=(15, 7), dpi=200)
plt.scatter(taxis['distance'], taxis['fare'], c=c, s=s)
plt.show()

# %%
taxis['pickup_zone'].value_counts()
# Out:
# pickup_zone
# Midtown Center                         230
# Upper East Side South                  211
# Penn Station/Madison Sq West           210
# Clinton East                           208
# Midtown East                           198
#                                       ...
# Homecrest                                1
# Bedford Park                             1
# Riverdale/North Riverdale/Fieldston      1
# Hollis                                   1
# Hillcrest/Pomonok                        1
# Name: count, Length: 194, dtype: int64

# %%
taxis['dropoff_zone'].value_counts()
# Out:
# dropoff_zone
# Upper East Side North        245
# Murray Hill                  220
# Midtown Center               215
# Upper East Side South        177
# Midtown East                 176
#                             ...
# Bensonhurst East               1
# Springfield Gardens South      1
# East Flushing                  1
# Brighton Beach                 1
# Ozone Park                     1
# Name: count, Length: 203, dtype: int64

# %%
jaipur = pd.DataFrame({
    'date':pd.date_range("05/12/25", periods=7),
    'student':np.random.randint(30, 50, 7)
})
jaipur
# Out:
#         date  student
# 0 2025-05-12       34
# 1 2025-05-13       38
# 2 2025-05-14       30
# 3 2025-05-15       44
# 4 2025-05-16       31
# 5 2025-05-17       39
# 6 2025-05-18       39

# %%
delhi = pd.DataFrame({
    'date':pd.date_range("05/12/25", periods=7),
    'student':np.random.randint(30, 60, 7)
})
delhi
# Out:
#         date  student
# 0 2025-05-12       35
# 1 2025-05-13       48
# 2 2025-05-14       42
# 3 2025-05-15       59
# 4 2025-05-16       48
# 5 2025-05-17       45
# 6 2025-05-18       58

# %%
pune = pd.DataFrame({
    'date':pd.date_range("05/12/25", periods=7),
    'student':np.random.randint(20, 45, 7)
})
pune
# Out:
#         date  student
# 0 2025-05-12       34
# 1 2025-05-13       32
# 2 2025-05-14       41
# 3 2025-05-15       31
# 4 2025-05-16       32
# 5 2025-05-17       33
# 6 2025-05-18       30

# %%
plt.barh(jaipur['date'], jaipur['student'])
# Out:
# <BarContainer object of 7 artists>

# %%
plt.bar(jaipur['date'], jaipur['student'])
ticks = plt.xticks(rotation=90)
plt.show()

# %%
jaipur
# Out:
#         date  student
# 0 2025-05-12       34
# 1 2025-05-13       38
# 2 2025-05-14       30
# 3 2025-05-15       44
# 4 2025-05-16       31
# 5 2025-05-17       39
# 6 2025-05-18       39

# %%
ticks
# Out:
# (array([20220., 20221., 20222., 20223., 20224., 20225., 20226.]),
#  [Text(20220.0, 0, '2025-05-12'),
#   Text(20221.0, 0, '2025-05-13'),
#   Text(20222.0, 0, '2025-05-14'),
#   Text(20223.0, 0, '2025-05-15'),
#   Text(20224.0, 0, '2025-05-16'),
#   Text(20225.0, 0, '2025-05-17'),
#   Text(20226.0, 0, '2025-05-18')])

# %%
ticks[0]
# Out:
# array([20220., 20221., 20222., 20223., 20224., 20225., 20226.])

# %%
plt.bar(jaipur['date'], jaipur['student'], facecolor='w', edgecolor='k')
plt.xticks(rotation=90)
for i in range(len(ticks[0])):
    plt.text(ticks[0][i], jaipur['student'][i] + 0.6, jaipur['student'][i])
plt.show()

# %% [markdown]
#     patches

# %% [markdown]
# ### subplots

# %%
i1
# Out:
# Index(['yellow', 'green'], dtype='object', name='color')

# %%
i2
# Out:
# Index(['credit card', 'cash'], dtype='object', name='payment')

# %%
v1
# Out:
# array([5451,  982], dtype=int64)

# %%
v2
# Out:
# array([4577, 1812], dtype=int64)

# %%
plt.figure(dpi=200)
plt.subplot(2,2,1)
plt.bar(i1, v1)
plt.subplot(2,2,2)
sns.scatterplot(x=taxis['distance'], y=taxis['fare'])
plt.subplot(2,2,3)
plt.plot(jaipur['student'])
plt.subplot(2,2,4)
plt.scatter(tips['total_bill'], tips['tip'])

# %%
fig = plt.figure(figsize=(15, 7), dpi=200)
fig.add_axes([0.0, 0.0, 0.5, 0.5])
fig.add_axes([0.5, 0.5, 0.5, 0.5])
# Out:
# <Axes: >
