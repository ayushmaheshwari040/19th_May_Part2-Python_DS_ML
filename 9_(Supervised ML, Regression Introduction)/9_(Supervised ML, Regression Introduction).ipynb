# %% [markdown]
# # **Supervised ML**

# %% [markdown]
# 1. Regression-> Predicting a continuous value as a dependent variable on the basis of independent variable. When target variable is numerical continuous/discrete variable.
# 2. Classification-> When target variable is categorical.

# %% [markdown]
# # Regression

# %% [markdown]
# 1. Linear Regression
# 2. Ploynomial Regression
# 3. SGD Regression-> Optimization Technique

# %% [markdown]
# # Terms in Regression

# %% [markdown]
# 1. Covariance-> Mathematical term to find the relationship between two variables.
# 2. Correation->
